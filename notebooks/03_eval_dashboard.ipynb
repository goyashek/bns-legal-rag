# %% [markdown]
# # 03 - Eval Dashboard
#
# Pull every eval result into one place so I can look at it all at once. This is the view
# I'll build the writeup around.
#
# panels:
# 1. RAGAS (the actual generative task): faithfulness / answer-relevancy /
#    context-precision / context-recall, split by easy/medium/hard.
# 2. BhashaBench-Legal comparability (with caveats): criminal-slice accuracy vs a no-RAG
#    baseline, and the IPC to BNS bridge accuracy reported on its own. Being honest about
#    what it does and doesn't show.
# 3. section-precision: P@5 / recall / citation-accuracy.
# 4. ablations (from notebook 02): hybrid vs dense/sparse, reranker on/off.
# 5. self-correction: how often the citation-validator catches a bad answer, plus one recorded
#    rejection case.
#
# note to self: RAGAS is what I trust most. BhashaBench is only external comparability and always
# with the caveats. Never quote it as a bare exam percentage, that would be misleading.

# %%
# fill in once eval modules are implemented
# from src.eval.ragas_eval import run_ragas_eval
# from src.eval.mcq_eval import run_mcq_eval
# from src.eval.section_precision import section_precision_at_k, section_recall
